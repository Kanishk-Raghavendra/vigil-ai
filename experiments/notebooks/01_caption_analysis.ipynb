# %% [markdown]
# # VIGIL Notebook 1: Caption Analysis
# ## Explainable Cross-Modal Verification Framework
#
# This notebook demonstrates **image-to-caption generation** using the BLIP model and analyzes caption quality for various images.
#
# **Goals:**
# - Load and visualize sample images
# - Generate captions using BLIP (Bootstrapping Language-Image Pre-training)
# - Analyze caption patterns and diversity
# - Visualize results with matplotlib
# - Cache captions for downstream analysis

# %% [markdown]
# ## Section 1: Setup and Configuration

# %%
# Import system libraries
import sys
from pathlib import Path
import json
import yaml
import random
import numpy as np

# Add project root to path
project_root = Path('.').resolve()
sys.path.insert(0, str(project_root))

# Set random seeds for reproducibility
random.seed(42)
np.random.seed(42)

print(f"Project root: {project_root}")
print(f"Python version: {sys.version}")
