# %% [markdown]
# # VIGIL Notebook 2: Claim Verification
# ## Extract and Verify Claims
# This notebook demonstrates claim extraction and verification using CLIP.

# %%
import sys, json
from pathlib import Path
import numpy as np
project_root = Path(".").resolve()
sys.path.insert(0, str(project_root))
print("✓ Environment initialized")
